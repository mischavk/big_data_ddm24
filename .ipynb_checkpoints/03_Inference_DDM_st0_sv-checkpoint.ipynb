# %%
import os
import sys
import scipy
from numba import njit, prange
import numpy as np
import scipy.stats as stats
import bayesflow as bf
import matplotlib.pyplot as plt
import seaborn as sns
from multiprocessing import Pool
import pickle
import tensorflow as tf
import pandas as pd 
from sklearn.covariance import EmpiricalCovariance
import priors_and_simulators as ps

# Suppress scientific notation for floats
np.set_printoptions(suppress=True)
RNG = np.random.default_rng(2023)

#Settings
# Path to data
PATH = '/home/mischa/Documents/bayesflow/prj_real_life_ddm/git/data/prepared_data/'

# Where to save files
PATH_TO_SAVE = '/home/mischa/Documents/bayesflow/prj_real_life_ddm/git/data/pickle_st0_sv/'
# Out:
# 2024-10-22 13:56:56.591396: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-22 13:56:56.614420: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-22 13:56:57.053016: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/mischa/miniconda3/envs/bf/lib/python3.10/site-packages/bayesflow/trainers.py:27: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# # Load neural networks from checkpoint

# %%
# Get network settings

PARAM_NAMES = [
    r"$v_{congruent}$",
    r"$v_{incongruent}$",
    r"$a_{congruent}$",
    r"$a_{incongruent}$",
    r"$\tau_{correct}$",
    r"$\tau_{error}$",
    r"$s_{tau}$",
    r"$s_{v}$"
]

prior = bf.simulation.Prior(prior_fun=ps.sv_st0_ddm_prior_fun, param_names=PARAM_NAMES)

prior_means, prior_stds = prior.estimate_means_and_stds(n_draws=10000)
prior_means = np.round(prior_means, decimals=1)
prior_stds = np.round(prior_stds, decimals=1)

simulator = bf.simulation.Simulator(simulator_fun=ps.sv_st0_ddm_simulator_fun)

model = bf.simulation.GenerativeModel(prior=prior, simulator=simulator, name="DDM")

def configurator(forward_dict):
    """Configure the output of the GenerativeModel for a BayesFlow setup."""

    out_dict = {}
    out_dict["summary_conditions"] = forward_dict["sim_data"]
    params = forward_dict["prior_draws"].astype(np.float32)
    # Standardize parameters
    out_dict["parameters"] = (params - prior_means) / prior_stds
    
    return out_dict

summary_net = bf.networks.SetTransformer(input_dim=4, summary_dim=20, name="ddm_summary")

inference_net = bf.networks.InvertibleNetwork(
    num_params=len(prior.param_names),
    coupling_settings={"dense_args": dict(kernel_regularizer=None), "dropout": False},
    coupling_design="spline",
    name="ddm_inference")


amortizer = bf.amortizers.AmortizedPosterior(inference_net, summary_net, name="ddm_amortizer",
                                            summary_loss_fun='MMD')

trainer = bf.trainers.Trainer(
        generative_model=model, amortizer=amortizer, configurator= configurator,
    checkpoint_path="ddm_net1")
# Out:
# INFO:root:Performing 2 pilot runs with the DDM model...
# INFO:root:Shape of parameter batch after 2 pilot simulations: (batch_size = 2, 8)
# INFO:root:Shape of simulation batch after 2 pilot simulations: (batch_size = 2, 120, 4)
# INFO:root:No optional prior non-batchable context provided.
# INFO:root:No optional prior batchable context provided.
# INFO:root:No optional simulation non-batchable context provided.
# INFO:root:No optional simulation batchable context provided.
# 2024-10-22 13:56:59.111520: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 13:56:59.205563: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 13:56:59.205769: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 13:56:59.208326: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 13:56:59.208510: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 13:56:59.208611: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 13:56:59.269503: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 13:56:59.269581: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 13:56:59.269630: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-22 13:56:59.269686: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7756 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6
# INFO:root:Loaded loss history from ddm_net1/history_100.pkl.
# INFO:root:Networks loaded from ddm_net1/ckpt-100
# INFO:root:Performing a consistency check with provided components...
# 2024-10-22 13:57:00.055647: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# INFO:root:Done.

# %% [markdown]
# # Run amortized inference

# %%
#This is where the magic happens

# 1. Store all data-set chunk names in a list
datasets = sorted(os.listdir(PATH))

# 2. For each chunk
for dataset_name in datasets:
    
        # 2.1 Load chunk
        loaded_pickle = pickle.load(open(PATH +str(dataset_name), "rb" ))
        
        X_test = loaded_pickle['data_array']
        y_test = loaded_pickle['outcome_array']
        rt_summaries = loaded_pickle['rt_summaries']
        
        print(str(dataset_name)+ " loaded")


        # 2.2 Estimate chunk

        samples_dm = np.concatenate([amortizer.sample(input_dict = {"summary_conditions": x}, n_samples=3000,
                                                  to_numpy=True) for x in np.array_split(X_test, 100)], axis=0)

        samples_dm = samples_dm * prior_stds + prior_means
        
        # Discard negative samples for positively bounded parameters
        samples_dm[:,:,2:8][samples_dm[:,:,2:8]<0] = np.nan  
        
        print(str(np.round(np.sum(np.isnan(samples_dm))/
                           (np.sum(np.isnan(samples_dm))+np.sum(~np.isnan(samples_dm))),
                           5)*100) +"% improper samples rejected")
        
        print(str(dataset_name)+ " inference done")

        # 2.3 Compute summaries of parameter posteriors: means, medians, stds, Q0.025, Q0.0975
        
        estimates = ps.compute_summaries(samples_dm)
        
        # Exclude people with less than 1000 proper posterior samples for at least one parameter
        estimates[np.sum((np.sum(np.isnan(samples_dm), axis=1)>2000), axis=1)>0,:] = np.nan 
        
        print(str(np.sum((np.sum(np.isnan(samples_dm), axis=1))>2000)) +
              " people with <1000 proper samples (for at least one parameter) excluded")

        # 2.4 Get empirical Mahalanobis distances for summary statistics provided by network
            
        summary_statistics_empirical = np.concatenate([trainer.amortizer.summary_net (x)
                                                       for x in np.array_split(X_test, 100)], axis=0)
        
        cov = EmpiricalCovariance().fit(summary_statistics_empirical)

        mahalanobis_empirical = cov.mahalanobis(summary_statistics_empirical)
        
        print(str(dataset_name)+ " Mahalanobis check done")

        
        # 2.5 Store everything together (serialized, pickle.dump) as a dict with keys 
        dict_to_store = {'data_array': X_test, 'est_array': estimates, "outcome_array": y_test,
                        'mahalanobis': mahalanobis_empirical, 'rt_summaries': rt_summaries}
        pickle.dump(dict_to_store,
                    open(PATH_TO_SAVE +"estimates_" +str(dataset_name),"wb"))
        print(str(dataset_name)+ " saving done")

# 3. Celebrate
# Out:
# prepared_False2003iat.p loaded
# 0.011000000000000001% improper samples rejected
# prepared_False2003iat.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2003iat.p Mahalanobis check done
# prepared_False2003iat.p saving done
# prepared_False2004iat.p loaded
# 0.016% improper samples rejected
# prepared_False2004iat.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2004iat.p Mahalanobis check done
# prepared_False2004iat.p saving done
# prepared_False2004iat2.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2004iat2.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2004iat2.p Mahalanobis check done
# prepared_False2004iat2.p saving done
# prepared_False2005iat.p loaded
# 0.017% improper samples rejected
# prepared_False2005iat.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2005iat.p Mahalanobis check done
# prepared_False2005iat.p saving done
# prepared_False2005iat2.p loaded
# 0.016% improper samples rejected
# prepared_False2005iat2.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2005iat2.p Mahalanobis check done
# prepared_False2005iat2.p saving done
# prepared_False2005iat3.p loaded
# 0.017% improper samples rejected
# prepared_False2005iat3.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2005iat3.p Mahalanobis check done
# prepared_False2005iat3.p saving done
# prepared_False2005iat4.p loaded
# 0.016% improper samples rejected
# prepared_False2005iat4.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2005iat4.p Mahalanobis check done
# prepared_False2005iat4.p saving done
# prepared_False2005iat5.p loaded
# 0.019% improper samples rejected
# prepared_False2005iat5.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2005iat5.p Mahalanobis check done
# prepared_False2005iat5.p saving done
# prepared_False2005iat6.p loaded
# 0.013% improper samples rejected
# prepared_False2005iat6.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2005iat6.p Mahalanobis check done
# prepared_False2005iat6.p saving done
# prepared_False2006iat.p loaded
# 0.017% improper samples rejected
# prepared_False2006iat.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2006iat.p Mahalanobis check done
# prepared_False2006iat.p saving done
# prepared_False2006iat2.p loaded
# 0.021% improper samples rejected
# prepared_False2006iat2.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2006iat2.p Mahalanobis check done
# prepared_False2006iat2.p saving done
# prepared_False2006iat3.p loaded
# 0.017% improper samples rejected
# prepared_False2006iat3.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2006iat3.p Mahalanobis check done
# prepared_False2006iat3.p saving done
# prepared_False2006iat4.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2006iat4.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2006iat4.p Mahalanobis check done
# prepared_False2006iat4.p saving done
# prepared_False2006iat5.p loaded
# 0.016% improper samples rejected
# prepared_False2006iat5.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2006iat5.p Mahalanobis check done
# prepared_False2006iat5.p saving done
# prepared_False2006iat6.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2006iat6.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2006iat6.p Mahalanobis check done
# prepared_False2006iat6.p saving done
# prepared_False2007iat.p loaded
# 0.016% improper samples rejected
# prepared_False2007iat.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2007iat.p Mahalanobis check done
# prepared_False2007iat.p saving done
# prepared_False2007iat2.p loaded
# 0.016% improper samples rejected
# prepared_False2007iat2.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2007iat2.p Mahalanobis check done
# prepared_False2007iat2.p saving done
# prepared_False2007iat3.p loaded
# 0.017% improper samples rejected
# prepared_False2007iat3.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2007iat3.p Mahalanobis check done
# prepared_False2007iat3.p saving done
# prepared_False2007iat4.p loaded
# 0.016% improper samples rejected
# prepared_False2007iat4.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2007iat4.p Mahalanobis check done
# prepared_False2007iat4.p saving done
# prepared_False2007iat5.p loaded
# 0.013999999999999999% improper samples rejected
# prepared_False2007iat5.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2007iat5.p Mahalanobis check done
# prepared_False2007iat5.p saving done
# prepared_False2007iat6.p loaded
# 0.017% improper samples rejected
# prepared_False2007iat6.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2007iat6.p Mahalanobis check done
# prepared_False2007iat6.p saving done
# prepared_False2007iat7.p loaded
# 0.016% improper samples rejected
# prepared_False2007iat7.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2007iat7.p Mahalanobis check done
# prepared_False2007iat7.p saving done
# prepared_False2007iat8.p loaded
# 0.017% improper samples rejected
# prepared_False2007iat8.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2007iat8.p Mahalanobis check done
# prepared_False2007iat8.p saving done
# prepared_False2008iat.p loaded
# 0.016% improper samples rejected
# prepared_False2008iat.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2008iat.p Mahalanobis check done
# prepared_False2008iat.p saving done
# prepared_False2008iat2.p loaded
# 0.016% improper samples rejected
# prepared_False2008iat2.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2008iat2.p Mahalanobis check done
# prepared_False2008iat2.p saving done
# prepared_False2008iat3.p loaded
# 0.016% improper samples rejected
# prepared_False2008iat3.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2008iat3.p Mahalanobis check done
# prepared_False2008iat3.p saving done
# prepared_False2008iat4.p loaded
# 0.016% improper samples rejected
# prepared_False2008iat4.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2008iat4.p Mahalanobis check done
# prepared_False2008iat4.p saving done
# prepared_False2008iat5.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2008iat5.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2008iat5.p Mahalanobis check done
# prepared_False2008iat5.p saving done
# prepared_False2008iat6.p loaded
# 0.017% improper samples rejected
# prepared_False2008iat6.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2008iat6.p Mahalanobis check done
# prepared_False2008iat6.p saving done
# prepared_False2009iat.p loaded
# 0.013999999999999999% improper samples rejected
# prepared_False2009iat.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2009iat.p Mahalanobis check done
# prepared_False2009iat.p saving done
# prepared_False2009iat2.p loaded
# 0.017% improper samples rejected
# prepared_False2009iat2.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2009iat2.p Mahalanobis check done
# prepared_False2009iat2.p saving done
# prepared_False2009iat3.p loaded
# 0.016% improper samples rejected
# prepared_False2009iat3.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2009iat3.p Mahalanobis check done
# prepared_False2009iat3.p saving done
# prepared_False2009iat4.p loaded
# 0.015% improper samples rejected
# prepared_False2009iat4.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2009iat4.p Mahalanobis check done
# prepared_False2009iat4.p saving done
# prepared_False2009iat5.p loaded
# 0.015% improper samples rejected
# prepared_False2009iat5.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2009iat5.p Mahalanobis check done
# prepared_False2009iat5.p saving done
# prepared_False2009iat6.p loaded
# 0.016% improper samples rejected
# prepared_False2009iat6.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2009iat6.p Mahalanobis check done
# prepared_False2009iat6.p saving done
# prepared_False2009iat7.p loaded
# 0.013999999999999999% improper samples rejected
# prepared_False2009iat7.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2009iat7.p Mahalanobis check done
# prepared_False2009iat7.p saving done
# prepared_False2009iat8.p loaded
# 0.017% improper samples rejected
# prepared_False2009iat8.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2009iat8.p Mahalanobis check done
# prepared_False2009iat8.p saving done
# prepared_False2010iat.p loaded
# 0.015% improper samples rejected
# prepared_False2010iat.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2010iat.p Mahalanobis check done
# prepared_False2010iat.p saving done
# prepared_False2010iat2.p loaded
# 0.016% improper samples rejected
# prepared_False2010iat2.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2010iat2.p Mahalanobis check done
# prepared_False2010iat2.p saving done
# prepared_False2010iat3.p loaded
# 0.016% improper samples rejected
# prepared_False2010iat3.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2010iat3.p Mahalanobis check done
# prepared_False2010iat3.p saving done
# prepared_False2010iat4.p loaded
# 0.015% improper samples rejected
# prepared_False2010iat4.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2010iat4.p Mahalanobis check done
# prepared_False2010iat4.p saving done
# prepared_False2010iat5.p loaded
# 0.016% improper samples rejected
# prepared_False2010iat5.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2010iat5.p Mahalanobis check done
# prepared_False2010iat5.p saving done
# prepared_False2010iat6.p loaded
# 0.016% improper samples rejected
# prepared_False2010iat6.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2010iat6.p Mahalanobis check done
# prepared_False2010iat6.p saving done
# prepared_False2011iat.p loaded
# 0.016% improper samples rejected
# prepared_False2011iat.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2011iat.p Mahalanobis check done
# prepared_False2011iat.p saving done
# prepared_False2011iat2.p loaded
# 0.017% improper samples rejected
# prepared_False2011iat2.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2011iat2.p Mahalanobis check done
# prepared_False2011iat2.p saving done
# prepared_False2011iat3.p loaded
# 0.017% improper samples rejected
# prepared_False2011iat3.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2011iat3.p Mahalanobis check done
# prepared_False2011iat3.p saving done
# prepared_False2011iat4.p loaded
# 0.016% improper samples rejected
# prepared_False2011iat4.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2011iat4.p Mahalanobis check done
# prepared_False2011iat4.p saving done
# prepared_False2011iat5.p loaded
# 0.016% improper samples rejected
# prepared_False2011iat5.p inference done
# 4 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2011iat5.p Mahalanobis check done
# prepared_False2011iat5.p saving done
# prepared_False2011iat6.p loaded
# 0.016% improper samples rejected
# prepared_False2011iat6.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2011iat6.p Mahalanobis check done
# prepared_False2011iat6.p saving done
# prepared_False2012iat.p loaded
# 0.015% improper samples rejected
# prepared_False2012iat.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2012iat.p Mahalanobis check done
# prepared_False2012iat.p saving done
# prepared_False2012iat2.p loaded
# 0.016% improper samples rejected
# prepared_False2012iat2.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2012iat2.p Mahalanobis check done
# prepared_False2012iat2.p saving done
# prepared_False2012iat3.p loaded
# 0.021% improper samples rejected
# prepared_False2012iat3.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2012iat3.p Mahalanobis check done
# prepared_False2012iat3.p saving done
# prepared_False2012iat4.p loaded
# 0.015% improper samples rejected
# prepared_False2012iat4.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2012iat4.p Mahalanobis check done
# prepared_False2012iat4.p saving done
# prepared_False2012iat5.p loaded
# 0.016% improper samples rejected
# prepared_False2012iat5.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2012iat5.p Mahalanobis check done
# prepared_False2012iat5.p saving done
# prepared_False2012iat6.p loaded
# 0.017% improper samples rejected
# prepared_False2012iat6.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2012iat6.p Mahalanobis check done
# prepared_False2012iat6.p saving done
# prepared_False2013iat.p loaded
# 0.017% improper samples rejected
# prepared_False2013iat.p inference done
# 7 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2013iat.p Mahalanobis check done
# prepared_False2013iat.p saving done
# prepared_False2013iat2.p loaded
# 0.017% improper samples rejected
# prepared_False2013iat2.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2013iat2.p Mahalanobis check done
# prepared_False2013iat2.p saving done
# prepared_False2013iat3.p loaded
# 0.016% improper samples rejected
# prepared_False2013iat3.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2013iat3.p Mahalanobis check done
# prepared_False2013iat3.p saving done
# prepared_False2013iat4.p loaded
# 0.016% improper samples rejected
# prepared_False2013iat4.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2013iat4.p Mahalanobis check done
# prepared_False2013iat4.p saving done
# prepared_False2013iat5.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2013iat5.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2013iat5.p Mahalanobis check done
# prepared_False2013iat5.p saving done
# prepared_False2013iat6.p loaded
# 0.012% improper samples rejected
# prepared_False2013iat6.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2013iat6.p Mahalanobis check done
# prepared_False2013iat6.p saving done
# prepared_False2014JanOctiat.p loaded
# 0.019% improper samples rejected
# prepared_False2014JanOctiat.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2014JanOctiat.p Mahalanobis check done
# prepared_False2014JanOctiat.p saving done
# prepared_False2014JanOctiat2.p loaded
# 0.019% improper samples rejected
# prepared_False2014JanOctiat2.p inference done
# 4 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2014JanOctiat2.p Mahalanobis check done
# prepared_False2014JanOctiat2.p saving done
# prepared_False2014JanOctiat3.p loaded
# 0.017% improper samples rejected
# prepared_False2014JanOctiat3.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2014JanOctiat3.p Mahalanobis check done
# prepared_False2014JanOctiat3.p saving done
# prepared_False2014JanOctiat4.p loaded
# 0.015% improper samples rejected
# prepared_False2014JanOctiat4.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2014JanOctiat4.p Mahalanobis check done
# prepared_False2014JanOctiat4.p saving done
# prepared_False2014JanOctiat5.p loaded
# 0.016% improper samples rejected
# prepared_False2014JanOctiat5.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2014JanOctiat5.p Mahalanobis check done
# prepared_False2014JanOctiat5.p saving done
# prepared_False2014Oct2015Janiat.p loaded
# 0.016% improper samples rejected
# prepared_False2014Oct2015Janiat.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2014Oct2015Janiat.p Mahalanobis check done
# prepared_False2014Oct2015Janiat.p saving done
# prepared_False2015FebMariat.p loaded
# 0.016% improper samples rejected
# prepared_False2015FebMariat.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2015FebMariat.p Mahalanobis check done
# prepared_False2015FebMariat.p saving done
# prepared_False2015MarDeciat.p loaded
# 0.017% improper samples rejected
# prepared_False2015MarDeciat.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2015MarDeciat.p Mahalanobis check done
# prepared_False2015MarDeciat.p saving done
# prepared_False2015MarDeciat2.p loaded
# 0.016% improper samples rejected
# prepared_False2015MarDeciat2.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2015MarDeciat2.p Mahalanobis check done
# prepared_False2015MarDeciat2.p saving done
# prepared_False2015MarDeciat3.p loaded
# 0.015% improper samples rejected
# prepared_False2015MarDeciat3.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2015MarDeciat3.p Mahalanobis check done
# prepared_False2015MarDeciat3.p saving done
# prepared_False2015MarDeciat4.p loaded
# 0.015% improper samples rejected
# prepared_False2015MarDeciat4.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2015MarDeciat4.p Mahalanobis check done
# prepared_False2015MarDeciat4.p saving done
# prepared_False2015MarDeciat5.p loaded
# 0.013999999999999999% improper samples rejected
# prepared_False2015MarDeciat5.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2015MarDeciat5.p Mahalanobis check done
# prepared_False2015MarDeciat5.p saving done
# prepared_False2015MarDeciat6.p loaded
# 0.013999999999999999% improper samples rejected
# prepared_False2015MarDeciat6.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2015MarDeciat6.p Mahalanobis check done
# prepared_False2015MarDeciat6.p saving done
# prepared_False2015MarDeciat7.p loaded
# 0.017% improper samples rejected
# prepared_False2015MarDeciat7.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2015MarDeciat7.p Mahalanobis check done
# prepared_False2015MarDeciat7.p saving done
# prepared_False2015MarDeciat8.p loaded
# 0.016% improper samples rejected
# prepared_False2015MarDeciat8.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2015MarDeciat8.p Mahalanobis check done
# prepared_False2015MarDeciat8.p saving done
# prepared_False2015MarDeciat9.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2015MarDeciat9.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2015MarDeciat9.p Mahalanobis check done
# prepared_False2015MarDeciat9.p saving done
# prepared_False2016JanSepiat.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2016JanSepiat.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016JanSepiat.p Mahalanobis check done
# prepared_False2016JanSepiat.p saving done
# prepared_False2016JanSepiat2.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2016JanSepiat2.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016JanSepiat2.p Mahalanobis check done
# prepared_False2016JanSepiat2.p saving done
# prepared_False2016JanSepiat3.p loaded
# 0.017% improper samples rejected
# prepared_False2016JanSepiat3.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016JanSepiat3.p Mahalanobis check done
# prepared_False2016JanSepiat3.p saving done
# prepared_False2016JanSepiat4.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2016JanSepiat4.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016JanSepiat4.p Mahalanobis check done
# prepared_False2016JanSepiat4.p saving done
# prepared_False2016JanSepiat5.p loaded
# 0.016% improper samples rejected
# prepared_False2016JanSepiat5.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016JanSepiat5.p Mahalanobis check done
# prepared_False2016JanSepiat5.p saving done
# prepared_False2016JanSepiat6.p loaded
# 0.016% improper samples rejected
# prepared_False2016JanSepiat6.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016JanSepiat6.p Mahalanobis check done
# prepared_False2016JanSepiat6.p saving done
# prepared_False2016JanSepiat7.p loaded
# 0.015% improper samples rejected
# prepared_False2016JanSepiat7.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016JanSepiat7.p Mahalanobis check done
# prepared_False2016JanSepiat7.p saving done
# prepared_False2016JanSepiat8.p loaded
# 0.016% improper samples rejected
# prepared_False2016JanSepiat8.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016JanSepiat8.p Mahalanobis check done
# prepared_False2016JanSepiat8.p saving done
# prepared_False2016JanSepiat9.p loaded
# 0.011000000000000001% improper samples rejected
# prepared_False2016JanSepiat9.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016JanSepiat9.p Mahalanobis check done
# prepared_False2016JanSepiat9.p saving done
# prepared_False2016iat.p loaded
# 0.024% improper samples rejected
# prepared_False2016iat.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016iat.p Mahalanobis check done
# prepared_False2016iat.p saving done
# prepared_False2016iat2.p loaded
# 0.024% improper samples rejected
# prepared_False2016iat2.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016iat2.p Mahalanobis check done
# prepared_False2016iat2.p saving done
# prepared_False2016iat3.p loaded
# 0.023% improper samples rejected
# prepared_False2016iat3.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016iat3.p Mahalanobis check done
# prepared_False2016iat3.p saving done
# prepared_False2016iat4.p loaded
# 0.023% improper samples rejected
# prepared_False2016iat4.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016iat4.p Mahalanobis check done
# prepared_False2016iat4.p saving done
# prepared_False2016iat5.p loaded
# 0.019% improper samples rejected
# prepared_False2016iat5.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2016iat5.p Mahalanobis check done
# prepared_False2016iat5.p saving done
# prepared_False2017iat.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2017iat.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat.p Mahalanobis check done
# prepared_False2017iat.p saving done
# prepared_False2017iat10.p loaded
# 0.021% improper samples rejected
# prepared_False2017iat10.p inference done
# /home/mischa/Documents/bayesflow/prj_real_life_ddm/git/priors_and_simulators.py:499: RuntimeWarning: Mean of empty slice
#   param_means = np.nanmean(samples_dm, axis=1)
# /home/mischa/miniconda3/envs/bf/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1095: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanmedian1d, axis, a, overwrite_input)
# /home/mischa/miniconda3/envs/bf/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1878: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/mischa/miniconda3/envs/bf/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1583: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat10.p Mahalanobis check done
# prepared_False2017iat10.p saving done
# prepared_False2017iat11.p loaded
# 0.02% improper samples rejected
# prepared_False2017iat11.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat11.p Mahalanobis check done
# prepared_False2017iat11.p saving done
# prepared_False2017iat12.p loaded
# 0.021% improper samples rejected
# prepared_False2017iat12.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat12.p Mahalanobis check done
# prepared_False2017iat12.p saving done
# prepared_False2017iat13.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2017iat13.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat13.p Mahalanobis check done
# prepared_False2017iat13.p saving done
# prepared_False2017iat14.p loaded
# 0.015% improper samples rejected
# prepared_False2017iat14.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat14.p Mahalanobis check done
# prepared_False2017iat14.p saving done
# prepared_False2017iat2.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2017iat2.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat2.p Mahalanobis check done
# prepared_False2017iat2.p saving done
# prepared_False2017iat3.p loaded
# 0.021% improper samples rejected
# prepared_False2017iat3.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat3.p Mahalanobis check done
# prepared_False2017iat3.p saving done
# prepared_False2017iat4.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2017iat4.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat4.p Mahalanobis check done
# prepared_False2017iat4.p saving done
# prepared_False2017iat5.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2017iat5.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat5.p Mahalanobis check done
# prepared_False2017iat5.p saving done
# prepared_False2017iat6.p loaded
# 0.023% improper samples rejected
# prepared_False2017iat6.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat6.p Mahalanobis check done
# prepared_False2017iat6.p saving done
# prepared_False2017iat7.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2017iat7.p inference done
# 4 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat7.p Mahalanobis check done
# prepared_False2017iat7.p saving done
# prepared_False2017iat8.p loaded
# 0.02% improper samples rejected
# prepared_False2017iat8.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat8.p Mahalanobis check done
# prepared_False2017iat8.p saving done
# prepared_False2017iat9.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2017iat9.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2017iat9.p Mahalanobis check done
# prepared_False2017iat9.p saving done
# prepared_False2018iat.p loaded
# 0.023% improper samples rejected
# prepared_False2018iat.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2018iat.p Mahalanobis check done
# prepared_False2018iat.p saving done
# prepared_False2018iat10.p loaded
# 0.023% improper samples rejected
# prepared_False2018iat10.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2018iat10.p Mahalanobis check done
# prepared_False2018iat10.p saving done
# prepared_False2018iat11.p loaded
# 0.021% improper samples rejected
# prepared_False2018iat11.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2018iat11.p Mahalanobis check done
# prepared_False2018iat11.p saving done
# prepared_False2018iat12.p loaded
# 0.024% improper samples rejected
# prepared_False2018iat12.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2018iat12.p Mahalanobis check done
# prepared_False2018iat12.p saving done
# prepared_False2018iat13.p loaded
# 0.023% improper samples rejected
# prepared_False2018iat13.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2018iat13.p Mahalanobis check done
# prepared_False2018iat13.p saving done
# prepared_False2018iat2.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2018iat2.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2018iat2.p Mahalanobis check done
# prepared_False2018iat2.p saving done
# prepared_False2018iat3.p loaded
# 0.025% improper samples rejected
# prepared_False2018iat3.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2018iat3.p Mahalanobis check done
# prepared_False2018iat3.p saving done
# prepared_False2018iat4.p loaded
# 0.024% improper samples rejected
# prepared_False2018iat4.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2018iat4.p Mahalanobis check done
# prepared_False2018iat4.p saving done
# prepared_False2018iat5.p loaded
# 0.021% improper samples rejected
# prepared_False2018iat5.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2018iat5.p Mahalanobis check done
# prepared_False2018iat5.p saving done
# prepared_False2018iat6.p loaded
# 0.024% improper samples rejected
# prepared_False2018iat6.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2018iat6.p Mahalanobis check done
# prepared_False2018iat6.p saving done
# prepared_False2018iat7.p loaded
# 0.02% improper samples rejected
# prepared_False2018iat7.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2018iat7.p Mahalanobis check done
# prepared_False2018iat7.p saving done
# prepared_False2018iat8.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2018iat8.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2018iat8.p Mahalanobis check done
# prepared_False2018iat8.p saving done
# prepared_False2018iat9.p loaded
# 0.026% improper samples rejected
# prepared_False2018iat9.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2018iat9.p Mahalanobis check done
# prepared_False2018iat9.p saving done
# prepared_False2019iat.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2019iat.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2019iat.p Mahalanobis check done
# prepared_False2019iat.p saving done
# prepared_False2019iat10.p loaded
# 0.021% improper samples rejected
# prepared_False2019iat10.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2019iat10.p Mahalanobis check done
# prepared_False2019iat10.p saving done
# prepared_False2019iat11.p loaded
# 0.024% improper samples rejected
# prepared_False2019iat11.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2019iat11.p Mahalanobis check done
# prepared_False2019iat11.p saving done
# prepared_False2019iat12.p loaded
# 0.025% improper samples rejected
# prepared_False2019iat12.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2019iat12.p Mahalanobis check done
# prepared_False2019iat12.p saving done
# prepared_False2019iat13.p loaded
# 0.029% improper samples rejected
# prepared_False2019iat13.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2019iat13.p Mahalanobis check done
# prepared_False2019iat13.p saving done
# prepared_False2019iat2.p loaded
# 0.025% improper samples rejected
# prepared_False2019iat2.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2019iat2.p Mahalanobis check done
# prepared_False2019iat2.p saving done
# prepared_False2019iat3.p loaded
# 0.025% improper samples rejected
# prepared_False2019iat3.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2019iat3.p Mahalanobis check done
# prepared_False2019iat3.p saving done
# prepared_False2019iat4.p loaded
# 0.025% improper samples rejected
# prepared_False2019iat4.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2019iat4.p Mahalanobis check done
# prepared_False2019iat4.p saving done
# prepared_False2019iat5.p loaded
# 0.023% improper samples rejected
# prepared_False2019iat5.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2019iat5.p Mahalanobis check done
# prepared_False2019iat5.p saving done
# prepared_False2019iat6.p loaded
# 0.026% improper samples rejected
# prepared_False2019iat6.p inference done
# 5 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2019iat6.p Mahalanobis check done
# prepared_False2019iat6.p saving done
# prepared_False2019iat7.p loaded
# 0.02% improper samples rejected
# prepared_False2019iat7.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2019iat7.p Mahalanobis check done
# prepared_False2019iat7.p saving done
# prepared_False2019iat8.p loaded
# 0.024% improper samples rejected
# prepared_False2019iat8.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2019iat8.p Mahalanobis check done
# prepared_False2019iat8.p saving done
# prepared_False2019iat9.p loaded
# 0.023% improper samples rejected
# prepared_False2019iat9.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2019iat9.p Mahalanobis check done
# prepared_False2019iat9.p saving done
# prepared_False2020iat.p loaded
# 0.026% improper samples rejected
# prepared_False2020iat.p inference done
# 5 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat.p Mahalanobis check done
# prepared_False2020iat.p saving done
# prepared_False2020iat10.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2020iat10.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat10.p Mahalanobis check done
# prepared_False2020iat10.p saving done
# prepared_False2020iat11.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2020iat11.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat11.p Mahalanobis check done
# prepared_False2020iat11.p saving done
# prepared_False2020iat12.p loaded
# 0.02% improper samples rejected
# prepared_False2020iat12.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat12.p Mahalanobis check done
# prepared_False2020iat12.p saving done
# prepared_False2020iat13.p loaded
# 0.02% improper samples rejected
# prepared_False2020iat13.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat13.p Mahalanobis check done
# prepared_False2020iat13.p saving done
# prepared_False2020iat14.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2020iat14.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat14.p Mahalanobis check done
# prepared_False2020iat14.p saving done
# prepared_False2020iat15.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2020iat15.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat15.p Mahalanobis check done
# prepared_False2020iat15.p saving done
# prepared_False2020iat16.p loaded
# 0.021% improper samples rejected
# prepared_False2020iat16.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat16.p Mahalanobis check done
# prepared_False2020iat16.p saving done
# prepared_False2020iat17.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2020iat17.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat17.p Mahalanobis check done
# prepared_False2020iat17.p saving done
# prepared_False2020iat18.p loaded
# 0.023% improper samples rejected
# prepared_False2020iat18.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat18.p Mahalanobis check done
# prepared_False2020iat18.p saving done
# prepared_False2020iat19.p loaded
# 0.021% improper samples rejected
# prepared_False2020iat19.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat19.p Mahalanobis check done
# prepared_False2020iat19.p saving done
# prepared_False2020iat2.p loaded
# 0.025% improper samples rejected
# prepared_False2020iat2.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat2.p Mahalanobis check done
# prepared_False2020iat2.p saving done
# prepared_False2020iat20.p loaded
# 0.021% improper samples rejected
# prepared_False2020iat20.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat20.p Mahalanobis check done
# prepared_False2020iat20.p saving done
# prepared_False2020iat21.p loaded
# 0.021% improper samples rejected
# prepared_False2020iat21.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat21.p Mahalanobis check done
# prepared_False2020iat21.p saving done
# prepared_False2020iat22.p loaded
# 0.021% improper samples rejected
# prepared_False2020iat22.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat22.p Mahalanobis check done
# prepared_False2020iat22.p saving done
# prepared_False2020iat23.p loaded
# 0.021% improper samples rejected
# prepared_False2020iat23.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat23.p Mahalanobis check done
# prepared_False2020iat23.p saving done
# prepared_False2020iat24.p loaded
# 0.023% improper samples rejected
# prepared_False2020iat24.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat24.p Mahalanobis check done
# prepared_False2020iat24.p saving done
# prepared_False2020iat25.p loaded
# 0.026% improper samples rejected
# prepared_False2020iat25.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat25.p Mahalanobis check done
# prepared_False2020iat25.p saving done
# prepared_False2020iat3.p loaded
# 0.027999999999999997% improper samples rejected
# prepared_False2020iat3.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat3.p Mahalanobis check done
# prepared_False2020iat3.p saving done
# prepared_False2020iat4.p loaded
# 0.019% improper samples rejected
# prepared_False2020iat4.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat4.p Mahalanobis check done
# prepared_False2020iat4.p saving done
# prepared_False2020iat5.p loaded
# 0.02% improper samples rejected
# prepared_False2020iat5.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat5.p Mahalanobis check done
# prepared_False2020iat5.p saving done
# prepared_False2020iat6.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2020iat6.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat6.p Mahalanobis check done
# prepared_False2020iat6.p saving done
# prepared_False2020iat7.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2020iat7.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat7.p Mahalanobis check done
# prepared_False2020iat7.p saving done
# prepared_False2020iat8.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_False2020iat8.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat8.p Mahalanobis check done
# prepared_False2020iat8.p saving done
# prepared_False2020iat9.p loaded
# 0.017% improper samples rejected
# prepared_False2020iat9.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2020iat9.p Mahalanobis check done
# prepared_False2020iat9.p saving done
# prepared_False2021iat.p loaded
# 0.021% improper samples rejected
# prepared_False2021iat.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat.p Mahalanobis check done
# prepared_False2021iat.p saving done
# prepared_False2021iat10.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2021iat10.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat10.p Mahalanobis check done
# prepared_False2021iat10.p saving done
# prepared_False2021iat11.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2021iat11.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat11.p Mahalanobis check done
# prepared_False2021iat11.p saving done
# prepared_False2021iat12.p loaded
# 0.019% improper samples rejected
# prepared_False2021iat12.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat12.p Mahalanobis check done
# prepared_False2021iat12.p saving done
# prepared_False2021iat13.p loaded
# 0.019% improper samples rejected
# prepared_False2021iat13.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat13.p Mahalanobis check done
# prepared_False2021iat13.p saving done
# prepared_False2021iat14.p loaded
# 0.027% improper samples rejected
# prepared_False2021iat14.p inference done
# 4 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat14.p Mahalanobis check done
# prepared_False2021iat14.p saving done
# prepared_False2021iat15.p loaded
# 0.021% improper samples rejected
# prepared_False2021iat15.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat15.p Mahalanobis check done
# prepared_False2021iat15.p saving done
# prepared_False2021iat16.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2021iat16.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat16.p Mahalanobis check done
# prepared_False2021iat16.p saving done
# prepared_False2021iat17.p loaded
# 0.024% improper samples rejected
# prepared_False2021iat17.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat17.p Mahalanobis check done
# prepared_False2021iat17.p saving done
# prepared_False2021iat18.p loaded
# 0.026% improper samples rejected
# prepared_False2021iat18.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat18.p Mahalanobis check done
# prepared_False2021iat18.p saving done
# prepared_False2021iat19.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2021iat19.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat19.p Mahalanobis check done
# prepared_False2021iat19.p saving done
# prepared_False2021iat2.p loaded
# 0.024% improper samples rejected
# prepared_False2021iat2.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat2.p Mahalanobis check done
# prepared_False2021iat2.p saving done
# prepared_False2021iat20.p loaded
# 0.024% improper samples rejected
# prepared_False2021iat20.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat20.p Mahalanobis check done
# prepared_False2021iat20.p saving done
# prepared_False2021iat3.p loaded
# 0.021% improper samples rejected
# prepared_False2021iat3.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat3.p Mahalanobis check done
# prepared_False2021iat3.p saving done
# prepared_False2021iat4.p loaded
# 0.02% improper samples rejected
# prepared_False2021iat4.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat4.p Mahalanobis check done
# prepared_False2021iat4.p saving done
# prepared_False2021iat5.p loaded
# 0.02% improper samples rejected
# prepared_False2021iat5.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat5.p Mahalanobis check done
# prepared_False2021iat5.p saving done
# prepared_False2021iat6.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_False2021iat6.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat6.p Mahalanobis check done
# prepared_False2021iat6.p saving done
# prepared_False2021iat7.p loaded
# 0.019% improper samples rejected
# prepared_False2021iat7.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_False2021iat7.p Mahalanobis check done
# prepared_False2021iat7.p saving done
# prepared_False2021iat8.p loaded
# 0.024% improper samples rejected
# prepared_False2021iat8.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# ...
# prepared_True2020iat23.p saving done
# prepared_True2020iat24.p loaded
# 0.023% improper samples rejected
# prepared_True2020iat24.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2020iat24.p Mahalanobis check done
# prepared_True2020iat24.p saving done
# prepared_True2020iat25.p loaded
# 0.021% improper samples rejected
# prepared_True2020iat25.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2020iat25.p Mahalanobis check done
# prepared_True2020iat25.p saving done
# prepared_True2020iat3.p loaded
# 0.027% improper samples rejected
# prepared_True2020iat3.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2020iat3.p Mahalanobis check done
# prepared_True2020iat3.p saving done
# prepared_True2020iat4.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_True2020iat4.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2020iat4.p Mahalanobis check done
# prepared_True2020iat4.p saving done
# prepared_True2020iat5.p loaded
# 0.021% improper samples rejected
# prepared_True2020iat5.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2020iat5.p Mahalanobis check done
# prepared_True2020iat5.p saving done
# prepared_True2020iat6.p loaded
# 0.016% improper samples rejected
# prepared_True2020iat6.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2020iat6.p Mahalanobis check done
# prepared_True2020iat6.p saving done
# prepared_True2020iat7.p loaded
# 0.019% improper samples rejected
# prepared_True2020iat7.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2020iat7.p Mahalanobis check done
# prepared_True2020iat7.p saving done
# prepared_True2020iat8.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_True2020iat8.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2020iat8.p Mahalanobis check done
# prepared_True2020iat8.p saving done
# prepared_True2020iat9.p loaded
# 0.018000000000000002% improper samples rejected
# prepared_True2020iat9.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2020iat9.p Mahalanobis check done
# prepared_True2020iat9.p saving done
# prepared_True2021iat.p loaded
# 0.021% improper samples rejected
# prepared_True2021iat.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat.p Mahalanobis check done
# prepared_True2021iat.p saving done
# prepared_True2021iat10.p loaded
# 0.024% improper samples rejected
# prepared_True2021iat10.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat10.p Mahalanobis check done
# prepared_True2021iat10.p saving done
# prepared_True2021iat11.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_True2021iat11.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat11.p Mahalanobis check done
# prepared_True2021iat11.p saving done
# prepared_True2021iat12.p loaded
# 0.023% improper samples rejected
# prepared_True2021iat12.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat12.p Mahalanobis check done
# prepared_True2021iat12.p saving done
# prepared_True2021iat13.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_True2021iat13.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat13.p Mahalanobis check done
# prepared_True2021iat13.p saving done
# prepared_True2021iat14.p loaded
# 0.024% improper samples rejected
# prepared_True2021iat14.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat14.p Mahalanobis check done
# prepared_True2021iat14.p saving done
# prepared_True2021iat15.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_True2021iat15.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat15.p Mahalanobis check done
# prepared_True2021iat15.p saving done
# prepared_True2021iat16.p loaded
# 0.024% improper samples rejected
# prepared_True2021iat16.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat16.p Mahalanobis check done
# prepared_True2021iat16.p saving done
# prepared_True2021iat17.p loaded
# 0.026% improper samples rejected
# prepared_True2021iat17.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat17.p Mahalanobis check done
# prepared_True2021iat17.p saving done
# prepared_True2021iat18.p loaded
# 0.027999999999999997% improper samples rejected
# prepared_True2021iat18.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat18.p Mahalanobis check done
# prepared_True2021iat18.p saving done
# prepared_True2021iat19.p loaded
# 0.027% improper samples rejected
# prepared_True2021iat19.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat19.p Mahalanobis check done
# prepared_True2021iat19.p saving done
# prepared_True2021iat2.p loaded
# 0.021% improper samples rejected
# prepared_True2021iat2.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat2.p Mahalanobis check done
# prepared_True2021iat2.p saving done
# prepared_True2021iat20.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_True2021iat20.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat20.p Mahalanobis check done
# prepared_True2021iat20.p saving done
# prepared_True2021iat3.p loaded
# 0.023% improper samples rejected
# prepared_True2021iat3.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat3.p Mahalanobis check done
# prepared_True2021iat3.p saving done
# prepared_True2021iat4.p loaded
# 0.023% improper samples rejected
# prepared_True2021iat4.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat4.p Mahalanobis check done
# prepared_True2021iat4.p saving done
# prepared_True2021iat5.p loaded
# 0.025% improper samples rejected
# prepared_True2021iat5.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat5.p Mahalanobis check done
# prepared_True2021iat5.p saving done
# prepared_True2021iat6.p loaded
# 0.024% improper samples rejected
# prepared_True2021iat6.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat6.p Mahalanobis check done
# prepared_True2021iat6.p saving done
# prepared_True2021iat7.p loaded
# 0.021% improper samples rejected
# prepared_True2021iat7.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat7.p Mahalanobis check done
# prepared_True2021iat7.p saving done
# prepared_True2021iat8.p loaded
# 0.022000000000000002% improper samples rejected
# prepared_True2021iat8.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat8.p Mahalanobis check done
# prepared_True2021iat8.p saving done
# prepared_True2021iat9.p loaded
# 0.024% improper samples rejected
# prepared_True2021iat9.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True2021iat9.p Mahalanobis check done
# prepared_True2021iat9.p saving done
# prepared_True20221iat.p loaded
# 0.024% improper samples rejected
# prepared_True20221iat.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20221iat.p Mahalanobis check done
# prepared_True20221iat.p saving done
# prepared_True20221iat2.p loaded
# 0.023% improper samples rejected
# prepared_True20221iat2.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20221iat2.p Mahalanobis check done
# prepared_True20221iat2.p saving done
# prepared_True20221iat3.p loaded
# 0.024% improper samples rejected
# prepared_True20221iat3.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20221iat3.p Mahalanobis check done
# prepared_True20221iat3.p saving done
# prepared_True20221iat4.p loaded
# 0.024% improper samples rejected
# prepared_True20221iat4.p inference done
# 0 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20221iat4.p Mahalanobis check done
# prepared_True20221iat4.p saving done
# prepared_True20221iat5.p loaded
# 0.027999999999999997% improper samples rejected
# prepared_True20221iat5.p inference done
# /home/mischa/Documents/bayesflow/prj_real_life_ddm/git/priors_and_simulators.py:499: RuntimeWarning: Mean of empty slice
#   param_means = np.nanmean(samples_dm, axis=1)
# /home/mischa/miniconda3/envs/bf/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1095: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanmedian1d, axis, a, overwrite_input)
# /home/mischa/miniconda3/envs/bf/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1878: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/mischa/miniconda3/envs/bf/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1583: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20221iat5.p Mahalanobis check done
# prepared_True20221iat5.p saving done
# prepared_True20221iat6.p loaded
# 0.027% improper samples rejected
# prepared_True20221iat6.p inference done
# 5 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20221iat6.p Mahalanobis check done
# prepared_True20221iat6.p saving done
# prepared_True20221iat7.p loaded
# 0.024% improper samples rejected
# prepared_True20221iat7.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20221iat7.p Mahalanobis check done
# prepared_True20221iat7.p saving done
# prepared_True20221iat8.p loaded
# 0.024% improper samples rejected
# prepared_True20221iat8.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20221iat8.p Mahalanobis check done
# prepared_True20221iat8.p saving done
# prepared_True20222iat.p loaded
# 0.024% improper samples rejected
# prepared_True20222iat.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20222iat.p Mahalanobis check done
# prepared_True20222iat.p saving done
# prepared_True20222iat2.p loaded
# 0.027999999999999997% improper samples rejected
# prepared_True20222iat2.p inference done
# /home/mischa/Documents/bayesflow/prj_real_life_ddm/git/priors_and_simulators.py:499: RuntimeWarning: Mean of empty slice
#   param_means = np.nanmean(samples_dm, axis=1)
# /home/mischa/miniconda3/envs/bf/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1095: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanmedian1d, axis, a, overwrite_input)
# /home/mischa/miniconda3/envs/bf/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1878: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/mischa/miniconda3/envs/bf/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1583: RuntimeWarning: All-NaN slice encountered
#   result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
# 4 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20222iat2.p Mahalanobis check done
# prepared_True20222iat2.p saving done
# prepared_True20222iat3.p loaded
# 0.027% improper samples rejected
# prepared_True20222iat3.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20222iat3.p Mahalanobis check done
# prepared_True20222iat3.p saving done
# prepared_True20222iat4.p loaded
# 0.027999999999999997% improper samples rejected
# prepared_True20222iat4.p inference done
# 6 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20222iat4.p Mahalanobis check done
# prepared_True20222iat4.p saving done
# prepared_True20222iat5.p loaded
# 0.033% improper samples rejected
# prepared_True20222iat5.p inference done
# 8 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20222iat5.p Mahalanobis check done
# prepared_True20222iat5.p saving done
# prepared_True20222iat6.p loaded
# 0.03% improper samples rejected
# prepared_True20222iat6.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20222iat6.p Mahalanobis check done
# prepared_True20222iat6.p saving done
# prepared_True20231iat.p loaded
# 0.027999999999999997% improper samples rejected
# prepared_True20231iat.p inference done
# 1 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20231iat.p Mahalanobis check done
# prepared_True20231iat.p saving done
# prepared_True20231iat2.p loaded
# 0.027999999999999997% improper samples rejected
# prepared_True20231iat2.p inference done
# 4 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20231iat2.p Mahalanobis check done
# prepared_True20231iat2.p saving done
# prepared_True20231iat3.p loaded
# 0.032% improper samples rejected
# prepared_True20231iat3.p inference done
# 4 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20231iat3.p Mahalanobis check done
# prepared_True20231iat3.p saving done
# prepared_True20231iat4.p loaded
# 0.027% improper samples rejected
# prepared_True20231iat4.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20231iat4.p Mahalanobis check done
# prepared_True20231iat4.p saving done
# prepared_True20231iat5.p loaded
# 0.027999999999999997% improper samples rejected
# prepared_True20231iat5.p inference done
# 4 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20231iat5.p Mahalanobis check done
# prepared_True20231iat5.p saving done
# prepared_True20231iat6.p loaded
# 0.03% improper samples rejected
# prepared_True20231iat6.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20231iat6.p Mahalanobis check done
# prepared_True20231iat6.p saving done
# prepared_True20232iat.p loaded
# 0.027% improper samples rejected
# prepared_True20232iat.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20232iat.p Mahalanobis check done
# prepared_True20232iat.p saving done
# prepared_True20232iat2.p loaded
# 0.027% improper samples rejected
# prepared_True20232iat2.p inference done
# 4 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20232iat2.p Mahalanobis check done
# prepared_True20232iat2.p saving done
# prepared_True20232iat3.p loaded
# 0.027999999999999997% improper samples rejected
# prepared_True20232iat3.p inference done
# 5 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20232iat3.p Mahalanobis check done
# prepared_True20232iat3.p saving done
# prepared_True20232iat4.p loaded
# 0.027% improper samples rejected
# prepared_True20232iat4.p inference done
# 2 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20232iat4.p Mahalanobis check done
# prepared_True20232iat4.p saving done
# prepared_True20232iat5.p loaded
# 0.027999999999999997% improper samples rejected
# prepared_True20232iat5.p inference done
# 3 people with <1000 proper samples (for at least one parameter) excluded
# prepared_True20232iat5.p Mahalanobis check done
# prepared_True20232iat5.p saving done

# %% [markdown]
# # Create csv

# %%
df = pd.DataFrame()
datasets = os.listdir(PATH_TO_SAVE)

for dataset in datasets:
        pickles = pickle.load(open(PATH_TO_SAVE +str(dataset), "rb" ))
        df_oneset = np.concatenate((pickles['est_array'],pickles['outcome_array'],pickles['rt_summaries'],
                                   np.expand_dims(pickles['mahalanobis'], axis=1)), axis=1)
        df_onesetpd = pd.DataFrame(data = df_oneset)
        df_onesetpd["dataset"] = str(dataset)      
        df = pd.concat([df, df_onesetpd])
        
        print(str(dataset)+" done")

df.columns = ["v_congruent", "v_incongruent", "a_congruent", "a_incongruent",
                 "tplus", "tminus", "st0", "sv",
                "v_congruent_median", "v_incongruent_median", "a_congruent_median", "a_incongruent_median",
                 "tplus_median","tminus_median", "st0_median", "sv_median",
                "v_congruent_std", "v_incongruent_std", "a_congruent_std", "a_incongruent_std",
                 "tplus_std","tminus_std", "st0_std", "sv_std",
                "v_congruent_q025", "v_incongruent_q025", "a_congruent_q025", "a_incongruent_q025",
                 "tplus_q025","tminus_q025", "st0_q025", "sv_q025",
                "v_congruent_q975", "v_incongruent_q975", "a_congruent_q975", "a_incongruent_q975",
                 "tplus_q975","tminus_q975", "st0_q975", "sv_q975",
              
                  "session_id", "age",
              
                "congruent_rt_correct", "congruent_rt_correct_sd",
                "congruent_rt_correct_q25", "congruent_rt_correct_q5", "congruent_rt_correct_q75",
                "congruent_rt_error", "congruent_rt_error_sd", 
                "congruent_rt_error_q25", "congruent_rt_error_q5", "congruent_rt_error_q75",
                "congruent_accuracy",
                                              
                "incongruent_rt_correct", "incongruent_rt_correct_sd",
                "incongruent_rt_correct_q25", "incongruent_rt_correct_q5", "incongruent_rt_correct_q75",
                "incongruent_rt_error", "incongruent_rt_error_sd",
                "incongruent_rt_error_q25", "incongruent_rt_error_q5", "incongruent_rt_error_q75",
                "incongruent_accuracy",
                                              
                "word_rt_correct", "word_rt_correct_sd",
                "word_rt_correct_q25", "word_rt_correct_q5", "word_rt_correct_q75",                                             
                "word_rt_error", "word_rt_error_sd", 
                "word_rt_error_q25", "word_rt_error_q5", "word_rt_error_q75",
                "word_accuracy",
                                              
                "picture_rt_correct", "picture_rt_correct_sd",
                "picture_rt_correct_q25", "picture_rt_correct_q5", "picture_rt_correct_q75",                                             
                "picture_rt_error", "picture_rt_error_sd",
                "picture_rt_error_q25", "picture_rt_error_q5", "picture_rt_error_q75",
                "picture_accuracy",
              
                 "mahalanobis_distance", "dataset"]

df.to_csv("df_sv_st0_ddm.csv", index=False)
# Out:
# estimates_prepared_False2015MarDeciat8.p done
# estimates_prepared_False2019iat4.p done
# estimates_prepared_False2019iat2.p done
# estimates_prepared_True2019iat6.p done
# estimates_prepared_False2009iat6.p done
# estimates_prepared_False2017iat13.p done
# estimates_prepared_False2021iat14.p done
# estimates_prepared_False2019iat5.p done
# estimates_prepared_False2012iat.p done
# estimates_prepared_True2018iat8.p done
# estimates_prepared_True20222iat5.p done
# estimates_prepared_False2017iat9.p done
# estimates_prepared_True20222iat4.p done
# estimates_prepared_False2006iat.p done
# estimates_prepared_False2017iat14.p done
# estimates_prepared_True2020iat13.p done
# estimates_prepared_True2018iat.p done
# estimates_prepared_True2019iat8.p done
# estimates_prepared_False2012iat3.p done
# estimates_prepared_True20221iat7.p done
# estimates_prepared_True2018iat7.p done
# estimates_prepared_False2020iat19.p done
# estimates_prepared_False2005iat3.p done
# estimates_prepared_False2020iat25.p done
# estimates_prepared_False2010iat4.p done
# estimates_prepared_False2019iat10.p done
# estimates_prepared_True20231iat3.p done
# estimates_prepared_False2019iat9.p done
# estimates_prepared_True20231iat.p done
# estimates_prepared_True2020iat6.p done
# estimates_prepared_False2017iat7.p done
# estimates_prepared_False2019iat13.p done
# estimates_prepared_False2020iat2.p done
# estimates_prepared_False2018iat13.p done
# estimates_prepared_False20232iat5.p done
# estimates_prepared_True20221iat4.p done
# estimates_prepared_True2020iat2.p done
# estimates_prepared_False2021iat11.p done
# estimates_prepared_False2009iat5.p done
# estimates_prepared_False2016JanSepiat4.p done
# estimates_prepared_False2017iat6.p done
# estimates_prepared_True2021iat.p done
# estimates_prepared_False2018iat3.p done
# estimates_prepared_False2020iat6.p done
# estimates_prepared_False2019iat6.p done
# estimates_prepared_False20232iat.p done
# estimates_prepared_True20231iat2.p done
# estimates_prepared_False20232iat3.p done
# estimates_prepared_False2010iat.p done
# estimates_prepared_False2018iat6.p done
# estimates_prepared_False2016JanSepiat2.p done
# estimates_prepared_False2008iat3.p done
# estimates_prepared_False2019iat11.p done
# estimates_prepared_True2018iat5.p done
# estimates_prepared_False2020iat.p done
# estimates_prepared_False20231iat4.p done
# estimates_prepared_True2021iat4.p done
# estimates_prepared_False2015MarDeciat4.p done
# estimates_prepared_True2020iat14.p done
# estimates_prepared_True2017iat11.p done
# estimates_prepared_True20231iat4.p done
# estimates_prepared_False20221iat8.p done
# estimates_prepared_True2020iat3.p done
# estimates_prepared_True2020iat16.p done
# estimates_prepared_False2005iat2.p done
# estimates_prepared_True2016iat.p done
# estimates_prepared_False2020iat7.p done
# estimates_prepared_False2009iat4.p done
# estimates_prepared_True2020iat.p done
# estimates_prepared_True2021iat20.p done
# estimates_prepared_False2019iat8.p done
# estimates_prepared_False2005iat4.p done
# estimates_prepared_True2020iat11.p done
# estimates_prepared_False20221iat6.p done
# estimates_prepared_False20231iat6.p done
# estimates_prepared_False20231iat5.p done
# estimates_prepared_True2021iat17.p done
# estimates_prepared_False2020iat10.p done
# estimates_prepared_False2007iat.p done
# estimates_prepared_False2016iat4.p done
# estimates_prepared_False2021iat19.p done
# estimates_prepared_True2018iat11.p done
# estimates_prepared_True2017iat10.p done
# estimates_prepared_False2005iat.p done
# estimates_prepared_False20221iat.p done
# estimates_prepared_False2021iat17.p done
# estimates_prepared_False2020iat23.p done
# estimates_prepared_False2016JanSepiat3.p done
# estimates_prepared_False2014JanOctiat.p done
# estimates_prepared_False2006iat5.p done
# estimates_prepared_False2014JanOctiat3.p done
# estimates_prepared_False2015MarDeciat2.p done
# estimates_prepared_False2021iat4.p done
# estimates_prepared_False2008iat6.p done
# estimates_prepared_True2003iat.p done
# estimates_prepared_False2020iat18.p done
# estimates_prepared_True2021iat16.p done
# estimates_prepared_False2013iat.p done
# estimates_prepared_True2016iat4.p done
# estimates_prepared_False2020iat4.p done
# estimates_prepared_True2005iat.p done
# estimates_prepared_False2017iat2.p done
# estimates_prepared_True2017iat14.p done
# estimates_prepared_False2007iat2.p done
# estimates_prepared_False2020iat21.p done
# estimates_prepared_False2015MarDeciat9.p done
# estimates_prepared_False2012iat5.p done
# estimates_prepared_False20231iat.p done
# estimates_prepared_True2021iat2.p done
# estimates_prepared_True2020iat20.p done
# estimates_prepared_True2021iat11.p done
# estimates_prepared_False2007iat7.p done
# estimates_prepared_True2017iat7.p done
# estimates_prepared_True2005iat3.p done
# estimates_prepared_False2015MarDeciat.p done
# estimates_prepared_True2021iat6.p done
# estimates_prepared_False2021iat.p done
# estimates_prepared_False20222iat4.p done
# estimates_prepared_False2018iat5.p done
# estimates_prepared_False2020iat17.p done
# estimates_prepared_True2005iat5.p done
# estimates_prepared_True20232iat4.p done
# estimates_prepared_False2007iat3.p done
# estimates_prepared_False2007iat5.p done
# estimates_prepared_True2019iat7.p done
# estimates_prepared_False2018iat7.p done
# estimates_prepared_False2018iat2.p done
# estimates_prepared_True20222iat.p done
# estimates_prepared_True2018iat3.p done
# estimates_prepared_False2009iat2.p done
# estimates_prepared_False2018iat8.p done
# estimates_prepared_True2021iat12.p done
# estimates_prepared_False2019iat7.p done
# estimates_prepared_True2019iat10.p done
# estimates_prepared_False2012iat4.p done
# estimates_prepared_False2014JanOctiat4.p done
# estimates_prepared_False2011iat4.p done
# estimates_prepared_True2019iat3.p done
# estimates_prepared_False2011iat3.p done
# estimates_prepared_True2018iat9.p done
# estimates_prepared_False2021iat18.p done
# estimates_prepared_False2020iat22.p done
# estimates_prepared_False2021iat20.p done
# estimates_prepared_False2017iat4.p done
# estimates_prepared_True2020iat8.p done
# estimates_prepared_False20222iat3.p done
# estimates_prepared_True2020iat25.p done
# estimates_prepared_True2019iat13.p done
# estimates_prepared_False2010iat3.p done
# estimates_prepared_False20231iat3.p done
# estimates_prepared_False2004iat2.p done
# estimates_prepared_False2016iat2.p done
# estimates_prepared_True2020iat19.p done
# estimates_prepared_False2021iat2.p done
# estimates_prepared_False2016iat3.p done
# estimates_prepared_False2018iat4.p done
# estimates_prepared_False20222iat5.p done
# estimates_prepared_True2021iat19.p done
# estimates_prepared_False2020iat16.p done
# estimates_prepared_False2017iat11.p done
# estimates_prepared_True20232iat2.p done
# estimates_prepared_True20231iat5.p done
# estimates_prepared_False2018iat12.p done
# estimates_prepared_False2007iat8.p done
# estimates_prepared_False20222iat.p done
# estimates_prepared_False2019iat12.p done
# estimates_prepared_True2017iat9.p done
# estimates_prepared_True2006iat3.p done
# estimates_prepared_False2021iat3.p done
# estimates_prepared_True2004iat2.p done
# estimates_prepared_False2020iat24.p done
# estimates_prepared_False2012iat6.p done
# estimates_prepared_False20222iat6.p done
# estimates_prepared_True2017iat13.p done
# estimates_prepared_False2016JanSepiat7.p done
# estimates_prepared_True2020iat10.p done
# estimates_prepared_True2018iat12.p done
# estimates_prepared_True20221iat8.p done
# estimates_prepared_False2006iat6.p done
# estimates_prepared_False2021iat9.p done
# estimates_prepared_False2017iat3.p done
# estimates_prepared_False20232iat4.p done
# estimates_prepared_False2004iat.p done
# estimates_prepared_True2021iat9.p done
# estimates_prepared_False2020iat11.p done
# estimates_prepared_False2021iat7.p done
# estimates_prepared_False2006iat2.p done
# estimates_prepared_True2018iat4.p done
# estimates_prepared_False20231iat2.p done
# estimates_prepared_True2017iat3.p done
# estimates_prepared_False2011iat6.p done
# estimates_prepared_True2021iat14.p done
# estimates_prepared_True2016iat5.p done
# estimates_prepared_True2005iat6.p done
# estimates_prepared_False2014JanOctiat5.p done
# estimates_prepared_True2018iat13.p done
# estimates_prepared_True2021iat8.p done
# estimates_prepared_True2018iat6.p done
# estimates_prepared_True2017iat8.p done
# estimates_prepared_False2020iat5.p done
# estimates_prepared_True2021iat10.p done
# estimates_prepared_False2021iat8.p done
# estimates_prepared_False2014JanOctiat2.p done
# estimates_prepared_False2020iat3.p done
# estimates_prepared_False20232iat2.p done
# estimates_prepared_False20221iat5.p done
# estimates_prepared_False2005iat6.p done
# estimates_prepared_True2020iat22.p done
# estimates_prepared_False2016JanSepiat.p done
# estimates_prepared_False2020iat13.p done
# estimates_prepared_False2017iat5.p done
# estimates_prepared_False2008iat2.p done
# estimates_prepared_False2011iat2.p done
# estimates_prepared_False2020iat20.p done
# estimates_prepared_False2008iat.p done
# estimates_prepared_False2010iat6.p done
# estimates_prepared_True2005iat4.p done
# estimates_prepared_True2018iat10.p done
# estimates_prepared_True2021iat7.p done
# estimates_prepared_False2016JanSepiat5.p done
# estimates_prepared_True2020iat21.p done
# estimates_prepared_False2003iat.p done
# estimates_prepared_False2005iat5.p done
# estimates_prepared_False2019iat.p done
# estimates_prepared_False2018iat9.p done
# estimates_prepared_True2020iat17.p done
# estimates_prepared_True20232iat3.p done
# estimates_prepared_False2015FebMariat.p done
# estimates_prepared_False20221iat2.p done
# estimates_prepared_True2019iat4.p done
# estimates_prepared_False2017iat10.p done
# estimates_prepared_True20221iat3.p done
# estimates_prepared_True20222iat2.p done
# estimates_prepared_True2020iat9.p done
# estimates_prepared_False2010iat5.p done
# estimates_prepared_False2020iat9.p done
# estimates_prepared_True2019iat.p done
# estimates_prepared_False2007iat6.p done
# estimates_prepared_False2009iat7.p done
# estimates_prepared_True20221iat5.p done
# estimates_prepared_True2017iat.p done
# estimates_prepared_False2021iat6.p done
# estimates_prepared_True2006iat4.p done
# estimates_prepared_True20222iat3.p done
# estimates_prepared_True2006iat2.p done
# estimates_prepared_False2020iat8.p done
# estimates_prepared_False20221iat4.p done
# estimates_prepared_True2021iat3.p done
# estimates_prepared_True2020iat5.p done
# estimates_prepared_True2020iat23.p done
# estimates_prepared_True20221iat.p done
# estimates_prepared_True2020iat12.p done
# estimates_prepared_False2017iat12.p done
# estimates_prepared_True2019iat9.p done
# estimates_prepared_True2017iat2.p done
# estimates_prepared_False2016JanSepiat6.p done
# estimates_prepared_False2016JanSepiat9.p done
# estimates_prepared_False2006iat3.p done
# estimates_prepared_False2011iat.p done
# estimates_prepared_True2017iat4.p done
# estimates_prepared_False2021iat5.p done
# estimates_prepared_True20221iat2.p done
# estimates_prepared_True2019iat12.p done
# estimates_prepared_False2021iat15.p done
# estimates_prepared_False2017iat.p done
# estimates_prepared_False2020iat12.p done
# estimates_prepared_False2018iat.p done
# estimates_prepared_False2009iat.p done
# estimates_prepared_False2017iat8.p done
# estimates_prepared_False2021iat10.p done
# estimates_prepared_True2017iat12.p done
# estimates_prepared_False2007iat4.p done
# estimates_prepared_False2020iat15.p done
# estimates_prepared_False20221iat7.p done
# estimates_prepared_True2005iat2.p done
# estimates_prepared_False2014Oct2015Janiat.p done
# estimates_prepared_False2012iat2.p done
# estimates_prepared_False2016iat5.p done
# estimates_prepared_False2015MarDeciat6.p done
# estimates_prepared_False2008iat4.p done
# estimates_prepared_False2021iat12.p done
# estimates_prepared_True2021iat13.p done
# estimates_prepared_False2009iat8.p done
# estimates_prepared_True2021iat18.p done
# estimates_prepared_False2018iat10.p done
# estimates_prepared_False2013iat4.p done
# estimates_prepared_False2013iat2.p done
# estimates_prepared_False2011iat5.p done
# estimates_prepared_False2016JanSepiat8.p done
# estimates_prepared_False2020iat14.p done
# estimates_prepared_True2018iat2.p done
# estimates_prepared_True2020iat7.p done
# estimates_prepared_True2019iat11.p done
# estimates_prepared_True20232iat.p done
# estimates_prepared_True2019iat2.p done
# estimates_prepared_True2019iat5.p done
# estimates_prepared_True2021iat15.p done
# estimates_prepared_True2016iat2.p done
# estimates_prepared_True20232iat5.p done
# estimates_prepared_False2010iat2.p done
# estimates_prepared_False2015MarDeciat3.p done
# estimates_prepared_False2016iat.p done
# estimates_prepared_True20231iat6.p done
# estimates_prepared_False2021iat16.p done
# estimates_prepared_True20222iat6.p done
# estimates_prepared_False2015MarDeciat5.p done
# estimates_prepared_True2020iat15.p done
# estimates_prepared_False2021iat13.p done
# estimates_prepared_True2017iat6.p done
# estimates_prepared_True20221iat6.p done
# estimates_prepared_False2013iat3.p done
# estimates_prepared_False20222iat2.p done
# estimates_prepared_True2004iat.p done
# estimates_prepared_False2015MarDeciat7.p done
# estimates_prepared_False2006iat4.p done
# estimates_prepared_False2009iat3.p done
# estimates_prepared_True2020iat4.p done
# estimates_prepared_True2021iat5.p done
# estimates_prepared_False20221iat3.p done
# estimates_prepared_True2017iat5.p done
# estimates_prepared_True2016iat3.p done
# estimates_prepared_True2020iat24.p done
# estimates_prepared_False2008iat5.p done
# estimates_prepared_False2019iat3.p done
# estimates_prepared_False2013iat5.p done
# estimates_prepared_True2020iat18.p done
# estimates_prepared_False2018iat11.p done
# estimates_prepared_False2013iat6.p done
# estimates_prepared_True2006iat.p done
